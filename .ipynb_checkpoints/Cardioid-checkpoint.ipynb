# %%
import sympy as sp
sp.init_printing()

# %% [markdown]
# We importes the <code>Sympy</code>.
#
# Nw we'd like to draw a cardioid. which is a very beautiful shape.
#
# The cardioid has an equation:
#
# $$ r(\theta) = 1-\sin(\theta) $$
#
# in polar coordinates $(x, y) \to (r, \theta)$ which are defined as:
#
# $$ \begin{Bmatrix} x(r, \theta) = r\cos{\theta} \\ y(r, \theta) = r\sin{\theta} \end{Bmatrix} $$
#
# And we can use these parametric equations to directly plot the cardioid:

# %%
theta = sp.symbols("theta", real=True)
r_cardioid = 1-sp.sin(theta)
x_cardioid = r_cardioid*sp.cos(theta)
y_cardioid = r_cardioid*sp.sin(theta)

# Use sympy's parametric plotting capabilities:
sp.plotting.plot_parametric((x_cardioid, y_cardioid), (theta, 0, 2*sp.pi))

# %%
print("This looks like a nice heart !")
# Out:
# This looks like a nice heart !

# %% [markdown]
# But instead of computing both $x$ and $y$, what we can do instead is to just use <code>Sympy</code>'s plotting capabilities and do a polar plot !:

# %%
# Plot the cardioid in a Sympy polar plot
#sp.plotting.plot_polar(r_cardioid, (theta, 0, 2*sp.pi))

# %% [markdown]
# Oh no !

# %% [markdown]
# Turns out that ChatGPT lied to us !
#
# There is in fact no <code>plot_parametric</code> function in <code>Sympy</code>'s plotting library !

# %% [markdown]
# Let's now do a Nephroid !:

# %%
a = 0.5  # You can change 'a' to scale the nephroid
x = 2 * a * (1 + sp.cos(theta)) * sp.cos(theta)
y = 2 * a * (1 + sp.cos(theta)) * sp.sin(theta)
sp.plotting.plot_parametric((x, y), (theta, 0, 2*sp.pi))
